# %%
import matplotlib.pyplot as plt
xa = [1.,1.,1.5,2.,1.,2.,2.]
ya = [1.,2.,3.,2.,2.,2.,1.]
linea, = plt.plot(xa,ya,'r--',linewidth = 6.0)
xl = [4.,3.5,3.,3.,3.,3.,3.]
yl = [1.,1.,1.5,2.0,2.5,1.,3.]
lineb, = plt.plot(xl,yl,'y+',linewidth = 6.0)
xi = [5.,5.,5.,5.,5.]
yi = [1.,1.5,2.0,2.5,3.]
linei, = plt.plot(xi,yi,'bo',linewidth = 6.0)
xn = [6.,6.,6.,6.,6.,6.5 ,6.7,6.9,7.2,7.5,7.5,7.5,7.5,7.5]
yn = [1.,1.5,2.0,2.5,3.,2.6,2.1,1.6,1.2,1.,1.5,2.0,2.5,3.]
linen, = plt.plot(xn,yn,'gx',linewidth = 6.0)
plt.show()
